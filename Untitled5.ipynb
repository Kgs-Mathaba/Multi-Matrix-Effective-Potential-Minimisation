# %%
#for lmax=8


import numpy as np
from scipy import linalg
#from itertools import permutations
from itertools import combinations
#from itertools import combinations_with_replacement
from scipy.optimize import minimize
from scipy.special import binom
from numpy.linalg import multi_dot
from timeit import default_timer as timer

def compare (Loop1, Loop2):

  """
  Compare two loops up to cyclic permutations
  """
  Length1 = len (Loop1)
  Length2 = len (Loop2)

  Same=False
  if (Length2 == 0) :
          Same=True
          return Same

  #Create warning if loops passed with different lengths #print ("lengths", Length1, Length2)

  Same = False
  for i in range (Length2):
    if np.array_equal (Loop1, np.roll(Loop2, i)):
        Same=True
        break

  return Same

def cyclic_generator (lp):

    """

    Input:   lp is a (1,len(lp)) ndarray
    Output:  is an array containing the first of the lexicographically sorted set of cyclic permutations of lp
             - example: [2,1,2,1] --> [1,2,1,2]
    """


    cyclic_perm = np.array([[0]*len(lp)]*len(lp))

    for i in range (len(lp)):
      cyclic_perm[i]= np.roll(lp, i)

    first_lexi_array = np.array (sorted([tuple(row) for row in cyclic_perm]))[0:1, :]

    return first_lexi_array

##################################################################################
    # old code
    # create an ordered set (no repeted elements) and store it back as an array
    # CyclicPermSet = np.array (sorted({tuple(row) for row in CyclicPerm}))
    # Fill in copies so that number of rows is len(Lp)
    # Rows= np.ma.size(CyclicPermSet, axis=0)
    # CyclicPermSet = np.vstack (([CyclicPermSet]*(len(Lp)/Rows)))
    # print ('Shape of CyclicPermSet=', np.shape(CyclicPermSet))
    # FlatCyclicArray = CyclicPermSet.flatten()[0:len(Lp)]###
############################################################################


def loops_of_length (loop_length):

    """
    Generates all distinct loops (up to cyclic permutations) of length loop_length
    Returns: Stack (matrix) of (1,loop_length) loop arrays

    """

    print("starting loops of length ", loop_length)

    """ Old code ---- uses set to remove identical permutations --- slow for large loops

    cyclic_set = cyclic_generator (np.array ([2]*loop_length)) #need for cyclic generator?
    big_big_perm_array=cyclic_set

    for i in range (1,loop_length):

        print ("starting with", i, "[1]s" )
        start_list = [1]*(i) + [2]*(loop_length-i)
        perm = permutations (start_list, loop_length) # list of permutations
        perm = np.array (sorted (set(perm)))          # removes identical permutations (set has only distinct elements)
        print ("sorted set generated")                                              # and converts to array
        big_perm_array = np.array([[0]*(loop_length)]*len(perm))
        for p in range (len(perm)):
            cyclic_set = cyclic_generator (perm [p])
            big_perm_array[p] = cyclic_set            # stores first of the lexicographically sorted cyclic permutations
        print ("removed identical cyclic permutations")                                              # in big_perm_array
        big_big_perm_array = np.vstack((big_big_perm_array,big_perm_array))

    cyclic_set = cyclic_generator (np.array ([1]*loop_length))
    big_big_perm_array = np.vstack((big_big_perm_array,cyclic_set))

    big_big_perm_set = np.array (sorted({tuple(row) for row in big_big_perm_array}))
    """
    """ Version -- 1  """

    all_ones = np.array ([1]*loop_length)
    big_big_perm_array=all_ones

    for i in range (1,loop_length):

        print ("starting with", i, "[2]s" )
        #no_2s=i
        comb = list(combinations (range(loop_length),i))
        #print ("print combinations")
        #for x in comb:
        #    print (x)
        #no_combinations = combinations (range(loop_length),i)
        #start=timer()
        #no_combinations=binom(loop_length,i)
        #end=timer()
        #print ("no_combinations", no_combinations, "time taken" , end-start)

        #start=timer()
        numb_combinations=len(comb)
        #end=timer()
        #print ("no_combinations with length", no_combinations, "time taken" , end-start)


        #big_perm_array = np.array([[0]*(loop_length)]*len(comb)) #may be avoidable by appending
        big_perm_array = np.array([[0]*(loop_length)]*numb_combinations)
        for p in range(numb_combinations):
            perm_distinct=list (all_ones)
            #print ("perm_distinct initial ")
            #print (perm_distinct)

            for comb_index in comb[p]:
                perm_distinct[comb_index]= 2
            #print ("perm_distinct for p ", p)
            #print (perm_distinct)
            big_perm_array[p]=cyclic_generator(np.array(perm_distinct))
        #print ("big_perm_array generated")
        #print (big_perm_array)                                             # and converts to array
        big_perm_array = np.array (sorted({tuple(row) for row in big_perm_array}))
        #print ("big_perm_array set generated")
        #print (big_perm_array)
        big_big_perm_array = np.vstack((big_big_perm_array,big_perm_array))

    big_big_perm_array = np.vstack((big_big_perm_array,np.array ([2]*loop_length)))

    #big_big_perm_set = np.array (sorted({tuple(row) for row in big_big_perm_array}))

    """
    Version 2 -- trying to iterate directly on combinations --- challenges with lists and arrays

    all_ones = np.array ([1]*loop_length)
    #cyclic_set = cyclic_generator (np.array ([2]*loop_length)) #need for cyclic generator?
    big_big_perm_array=all_ones

    for i in range (1,loop_length):

        print ("starting with", i, "[2]s" )
        #no_2s=i
        #comb = list(combinations (range(loop_length),i))
        #print ("print combinations")
        #for x in comb:
        #    print (x)
        #no_cominations = combinations (range(loop_length),i)
        #big_perm_array = np.array([[0]*(loop_length)]*len(comb)) #may be avoidable by appending
        big_perm_array=[]
        print ("big_perm_array empty")
        print (big_perm_array)
        print ("type", type(big_perm_array))
        for comb_tuple in combinations (range(loop_length),i):
            perm_distinct=list (all_ones)
            print ("perm_distinct initial ")
            print (perm_distinct)

            for comb_index in comb_tuple:
                perm_distinct[comb_index]= 2
            print ("perm_distinct for comb_tuple ", comb_tuple)
            print (perm_distinct)
            big_perm_array.append(cyclic_generator(np.array(perm_distinct)))
            #big_perm_array.append(cyclic_generator((perm_distinct)))
        print ("big_perm_array generated")
        print (big_perm_array)
        print ("type", type(big_perm_array))                                          # and converts to array
        big_perm_array = np.array (sorted({tuple(row) for row in np.array(big_perm_array)}))
        print ("big_perm_array set generated")
        print (big_perm_array)
        big_big_perm_array = np.vstack((big_big_perm_array,big_perm_array))

    big_big_perm_array = np.vstack((big_big_perm_array,np.array ([2]*loop_length)))

    """


    return big_big_perm_array


#############  bag of tricks ################
#def unique_perms(series):
    #return {"".join(p) for p in permutations(series)}

#print ( unique_perms('1122'))
#print(sorted(unique_perms('1122')))
#print (type(sorted(unique_perms('1122'))))
########################################

def effect_pot(x_N_2, omega_dim, num_loops,litte_omega_dim, nt_hooft, c_coupling, g3_coupling,g4_coupling):

    global loop
    global omega
    global little_omega
    global LnJ
    """ imported - checked
    matrices_array =np.zeros((2,nt_hooft,nt_hooft),dtype=complex)
    matrices_array[0] = np.diag(x_N_2[0:nt_hooft])
    #print ("full matrix 1", matrices_array[0]) #keep it real for the time being
    temp_matrix_2 = np.reshape (x_N_2[nt_hooft:nt_hooft**2+nt_hooft], (nt_hooft,nt_hooft))
    real_matrix_2 = np.triu(temp_matrix_2)
    real_matrix_2 = real_matrix_2+real_matrix_2.T-np.diag(np.diag(temp_matrix_2))
    imag_matrix_2 = np.tril(temp_matrix_2)
    imag_matrix_2 = imag_matrix_2-imag_matrix_2.T
    matrices_array[1]=real_matrix_2+imag_matrix_2*1.j
    verified same as v1 """
    ##print ("Called function")
    #  Extract info from flat array
    #print ("Started function")#
    #print ("N =", nt_hooft, "length = ", len(x_N_2))#
    #matrix_1_diagonal= x_N_2[0:nt_hooft]
    matrices_array =np.zeros((2,nt_hooft,nt_hooft),dtype=complex)
    #print (matrices_array)#
    matrices_array[0] = np.diag(x_N_2[0:nt_hooft])
    #matrices_array[0]=matrix_1
    ##print ("full matrix 1", matrices_array[0]) #keep it real for the time being
    temp_matrix_2 = np.reshape (x_N_2[nt_hooft:nt_hooft**2+nt_hooft], (nt_hooft,nt_hooft))
    real_matrix_2 = np.triu(temp_matrix_2)
    real_matrix_2 = real_matrix_2+real_matrix_2.T-np.diag(np.diag(temp_matrix_2))
    imag_matrix_2 = np.tril(temp_matrix_2)
    imag_matrix_2 = imag_matrix_2-imag_matrix_2.T
    #print ("real part", real_matrix_2)
    #print ("imaginary part", imag_matrix_2)
    matrices_array[1]=real_matrix_2+imag_matrix_2*1.j
    ##print ("full matrix 2", matrices_array[1])
    #print (np.dot (matrix_1,matrix_2))
    #matrices_array =
    #print ("array of matrices", matrices_array)

    """
    for i in range (1,num_loops+1):
        loop_matrix=matrices_array[loop_list[i][0]-1]
        #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
        #print (loop_matrix)
        for k in range(1,len(loop_list[i])):
            #print (k)
            #loop_matrix=loop_matrix @ matrices_array[loop_list[i][k]-1]
            loop_matrix=np.dot(loop_matrix,matrices_array[loop_list[i][k]-1])
        #print("after k loop, loop matrix", loop_matrix)
        #print ("Are loops real ? ", np.trace(loop_matrix) /( np.power(nt_hooft, (len(loop_list[i])+2)/2)))
        loop[i]=np.trace(loop_matrix) /( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #note: not declared as complex; always returns real value
        #print ("loop[",i,"]", loop[i])
    loop[0]=1.0

    """
    for i in range (1,num_loops+1):
        loop_matrix=matrices_array[loop_list[i][0]-1]
        #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
        #print (loop_matrix)
        for k in range(1,len(loop_list[i])):
            #print ("loop", i, "word", k, "loop_list", loop_list[i][k], (loop_list[i][k]==1))
            if loop_list[i][k]==1 :
                loop_matrix=loop_matrix * x_N_2[0:nt_hooft]          #[k]#matrices_list[loop_list[i][k]-1]
            else:
                loop_matrix=np.dot(loop_matrix,matrices_array[1])#[loop_list[i][k]-1]
        #print("after k loop, loop matrix", loop_matrix)
        #loop[i]=(np.trace(loop_matrix)).real /( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #v3
        #print ("loop[",i,"]", loop[i])
        loop[i]=np.trace(loop_matrix)/( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #v3
        #print ("loop[",i,"]", loop[i])
    loop[0]=1.0


    """ old code
    ##for i in range (num_loops+1):
        ##print ("loop[",i,"]", loop[i])
    #start building big omega
    #omega = [[(i+1)*(j+1)*loop[i+j]for i in range(omega_size)]for j in range(omega_size)]

    for i in range (omega_dim):
        for j in range (omega_dim):
            omega[i,j]=0.
            for k in range (num_loops+1):
                omega[i,j]+= y[i+1,j+1,k] * loop[k]

    ##print ("omega", omega)

    #print ("eigenvalues", linalg.eigvals(omega))


    for i in range (2,omega_dim):
        little_omega[i]=0.
        for j in range (litte_omega_dim+1):
            for k in range (litte_omega_dim+1):
                little_omega[i]+=z[i+1,j,k]*loop[j]*loop[k]

    ##print ("little_omega", little_omega)
    LnJ = np.linalg.solve(omega, little_omega)

    """
    """ np.sum is faster but memory demanding
    omega=np.sum (np.array([[[y[i+1,j+1,k] * loop[k] for i in range (omega_dim)] for j in range (omega_dim)] for k in range (num_loops+1)]),axis=0)

    little_omega=np.sum (np.array([[[z[i+1,j,k]*loop[j]*loop[k] for i in range (omega_dim)] for j in range (litte_omega_dim+1)] for k in range (litte_omega_dim+1)]),axis=(0,1))
    #little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0 + c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0
    little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0 + c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0-g4_coupling*omega[:,9]-g4_coupling*omega[:,14]
    """

    omega=np.zeros ((omega_dim,omega_dim),dtype=complex)
    for i in range (omega_dim):
        for j in range (omega_dim):
            omega[i,j]=0.0
            for k in range (num_loops+1):
                omega[i,j]+=y[i+1,j+1,k] * loop[k]

    little_omega=np.zeros ((omega_dim),dtype=complex)
    for i in range (omega_dim):
        little_omega[i]=0.0
        for j in range (litte_omega_dim+1):
            for k in range (j,litte_omega_dim+1):
                little_omega[i]+= z[i+1,j,k]*loop[j]*loop[k]
    little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0 + c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0-g4_coupling*omega[:,9]-g4_coupling*omega[:,14]





    """
    det=np.linalg.det(omega)
    c=np.array(omega)
    #print (c)
    for j in range(omega_dim):
        c[:,j]=little_omega
        LnJ[j]=np.linalg.det(c)/det
        c[:,j]=omega[:,j]
    """

    LnJ = np.linalg.solve(omega, little_omega)
    # Obtain value of collective effective potential
    large_n_energy = np.dot(little_omega , LnJ)/8.0

    print("large_n_energy", large_n_energy)


    return large_n_energy.real

def effect_pot_grad(x_N_2, omega_dim, num_loops,litte_omega_dim, nt_hooft, c_coupling, g3_coupling, g4_coupling):

    #global loop
    #global omega
    #global little_omega
    ##print ("Called gradient")
    #  Extract info from flat array
    #print ("Started function")#
    #print ("N =", nt_hooft, "length = ", len(x_N_2))#
    #matrix_1_diagonal= x_N_2[0:nt_hooft]
    matrices_array =np.zeros((2,nt_hooft,nt_hooft),dtype=complex)
    #print (matrices_array)#
    matrices_array[0] = np.diag(x_N_2[0:nt_hooft])
    #matrices_array[0]=matrix_1
    ##print ("full matrix 1", matrices_array[0])
    temp_matrix_2 = np.reshape (x_N_2[nt_hooft:nt_hooft**2+nt_hooft], (nt_hooft,nt_hooft))
    real_matrix_2 = np.triu(temp_matrix_2)
    real_matrix_2 = real_matrix_2+real_matrix_2.T-np.diag(np.diag(temp_matrix_2))
    imag_matrix_2 = np.tril(temp_matrix_2)
    imag_matrix_2 = imag_matrix_2-imag_matrix_2.T
    #print ("real part", real_matrix_2)
    #print ("imaginary part", imag_matrix_2)
    matrices_array[1]=real_matrix_2+imag_matrix_2*1.j
    ##print ("full matrix 2", matrices_array[1])
    #print (np.dot (matrix_1,matrix_2))
    #matrices_array =
    #print ("array of matrices", matrices_array)
    """ older version
    for i in range (1,num_loops+1):
        loop_matrix=matrices_array[loop_list[i][0]-1]
        #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
        #print (loop_matrix)
        for k in range(1,len(loop_list[i])):
            #print (k)
            #loop_matrix=loop_matrix @ matrices_array[loop_list[i][k]-1]
            loop_matrix=np.dot(loop_matrix,matrices_array[loop_list[i][k]-1])
        #print("after k loop, loop matrix", loop_matrix)
        #up to lmax=4 all loops real_matrix_2
        #print ("Are loops real ? ", np.trace(loop_matrix) /( np.power(nt_hooft, (len(loop_list[i])+2)/2)))
        loop[i]=np.trace(loop_matrix) /( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #note: not declared as complex; always returns real value
        #print ("loop[",i,"]", loop[i])
    loop[0]=1.0

    """
    for i in range (1,num_loops+1):
        loop_matrix=matrices_array[loop_list[i][0]-1]
        #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
        #print (loop_matrix)
        for k in range(1,len(loop_list[i])):
            #print ("loop", i, "word", k, "loop_list", loop_list[i][k], (loop_list[i][k]==1))
            if loop_list[i][k]==1 :
                loop_matrix=loop_matrix * x_N_2[0:nt_hooft]          #[k]#matrices_list[loop_list[i][k]-1]
            else:
                loop_matrix=np.dot(loop_matrix,matrices_array[1])#[loop_list[i][k]-1]
        #print("after k loop, loop matrix", loop_matrix)
        #loop[i]=(np.trace(loop_matrix)).real /( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #v3
        loop[i]=np.trace(loop_matrix)/( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #v3

        #print ("loop[",i,"]", loop[i])
    loop[0]=1.0

    #print ("geenrated loops")

    ##for i in range (num_loops+1):
        ##print ("loop[",i,"]", loop[i])

    #start building big omega
    #omega = [[(i+1)*(j+1)*loop[i+j]for i in range(omega_size)]for j in range(omega_size)]
    """ Old code
    for i in range (omega_dim):
        for j in range (omega_dim):
            omega[i,j]=0.
            for k in range (num_loops+1):
                omega[i,j]+= y[i+1,j+1,k] * loop[k]

    ##print ("omega", omega)

    #print ("eigenvalues", linalg.eigvals(omega))
    #inconsistency with omega_size=omega_dim
    for i in range (2,omega_dim):
        little_omega[i]=0.
        for j in range (litte_omega_dim+1):
            for k in range (litte_omega_dim+1):
                little_omega[i]+=z[i+1,j,k]*loop[j]*loop[k]

    ##print ("little_omega", little_omega)

    LnJ = np.linalg.solve(omega, little_omega)
    """
    """
    #print ("starting Omega")
    omega=np.sum (np.array([[[y[i+1,j+1,k] * loop[k] for i in range (omega_dim)] for j in range (omega_dim)] for k in range (num_loops+1)]),axis=0)
    #print ("starting little omega")
    little_omega=np.sum (np.array([[[z[i+1,j,k]*loop[j]*loop[k] for i in range (omega_dim)] for j in range (litte_omega_dim+1)] for k in range (litte_omega_dim+1)]),axis=(0,1))
    #little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0+ c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0
    little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0+ c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0-g4_coupling*omega[:,9]-g4_coupling*omega[:,14]
    """
    #print ("started inversion")

    omega=np.zeros ((omega_dim,omega_dim),dtype=complex)
    for i in range (omega_dim):
        for j in range (omega_dim):
            omega[i,j]=0.0
            for k in range (num_loops+1):
                omega[i,j]+=y[i+1,j+1,k] * loop[k]

    little_omega=np.zeros ((omega_dim),dtype=complex)
    for i in range (omega_dim):
        little_omega[i]=0.0
        for j in range (litte_omega_dim+1):
            for k in range (j,litte_omega_dim+1):
                little_omega[i]+= z[i+1,j,k]*loop[j]*loop[k]
    little_omega+=- omega[:,2]/2.0-omega[:,4]/2.0 + c_coupling*omega[:,3]-g3_coupling*omega[:,5]/3.0-g3_coupling*omega[:,8]/3.0-g4_coupling*omega[:,9]-g4_coupling*omega[:,14]

    """ cubic lmax=8 giving nan
    det=np.linalg.det(omega)
    c=np.array(omega)
    #print (c)
    for j in range(omega_dim):
        c[:,j]=little_omega
        LnJ[j]=np.linalg.det(c)/det
        c[:,j]=omega[:,j]
    """
    LnJ = np.linalg.solve(omega, little_omega)

    ##print ("LnJ", LnJ)

    # Obtain value of collective effective potential
    #large_n_energy = np.dot(little_omega , LnJ)/8.0 + loop[3]/2. + loop[5]/2.
    #print ("sarted dervi wrt master variables")
    grad_array_1=np.zeros((num_loops+1,nt_hooft),dtype=complex)##
    grad_array_2=np.zeros((num_loops+1,nt_hooft,nt_hooft),dtype=complex)
    grad_list_2=np.zeros((num_loops+1,nt_hooft*nt_hooft),dtype=complex)

    grad_array_1[1]= np.ones(nt_hooft)    # this assumes first 3 loops are [] [1] [2]
    grad_array_2[2]= np.identity(nt_hooft)
    grad_list_2[2]=(grad_array_2[2]).flatten()
    for i in range (3,num_loops+1):    #assumes first 3 loops will alwyas be the same
    #loop_matrix=matrices_array[loop_list[i][0]-1]
    #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
    #print (loop_matrix)
        for k in range(len(loop_list[i])):
        #print (k)
        #loop_matrix=loop_matrix @ matrices_array[loop_list[i][k]-1]
            loop_left = loop_list[i][0:k]
        #print (loop_left)
            loop_right= loop_list[i][k+1:len(loop_list[i])]
        #print (loop_right)
            loop_grad=np.concatenate ((loop_right , loop_left))
            ##print("loop",i,
                ##"bit matrix", k,
                ##"loop grad", loop_grad          )
            grad_len = len(loop_grad)
            grad_matrix=matrices_array[loop_grad[0]-1]
            ##print("started with matrix",loop_grad[0] )
            if grad_len > 1 :
                for l in range(1,grad_len):
                    if loop_grad[l]==1 :
                        grad_matrix=grad_matrix * x_N_2[0:nt_hooft]          #[k]#matrices_list[loop_list[i][k]-1]
                    else:
                        grad_matrix=np.dot(grad_matrix,matrices_array[1])
            if loop_list[i][k]==1 :
                #grad_array[i,0]+=grad_matrix.T
                grad_array_1[i]+=np.diagonal(grad_matrix.real)
                #print("der wrt 1 ", grad_array_1[i])
            else :
                """
                previous code
                grad_array_2[i]+=grad_matrix.T
                print("full der wrt 2", grad_array_2[i])
                real_matrix_2 = np.triu(grad_array_2[i].real)
                #print ("real der wrt 2", real_matrix_2)
                imag_matrix_2 = np.tril(grad_array_2[i].imag)
                #print ("imag der wrt 2", imag_matrix_2)
                #diag_matrix_2 = np.diag(np.diag(grad_array_2[i]))
                #print ("diagonal part", diag_matrix_2)
                #print (real_matrix_2+imag_matrix_2)
                #print (np.shape(real_matrix_2+imag_matrix_2))
                grad_list_2[i]=(real_matrix_2+imag_matrix_2).flatten()#+diag_matrix_2)
                """
                grad_array_2[i]+=grad_matrix

        ##print("der wrt 1 ", grad_array_1[i])
        ##print("full der wrt 2", grad_array_2[i])
        upper_matrix_2 = np.triu((grad_array_2[i] + grad_array_2[i].T))- np.diag(np.diag(grad_array_2[i]))
        lower_matrix_2 = -1.0j*(np.tril((grad_array_2[i] - grad_array_2[i].T)))
        grad_array_2[i] = upper_matrix_2+lower_matrix_2
        ##print("full der wrt 2 after projection ", grad_array_2[i])
        grad_list_2[i]=(grad_array_2[i]).flatten()

        """
    for i in range (num_loops+1):
        print("Loop ", i , "Matrix 1", grad_array_1[i])
    for i in range (num_loops+1):
        print("Loop ", i , "Matrix 2", grad_array_2[i])
        print("Loop ", i , "Matrix 2 flat", grad_list_2[i])
            #grad_matrix_1
            """
            #loop_matrix=np.dot(loop_matrix,matrices_array[loop_list[i][k]-1])
    #print("after k loop, loop matrix", loop_matrix)
        #loop[i]=np.trace(loop_matrix) /( np.power(nt_hooft, (len(loop_list[i])+2)/2)) #note: not declared as complex; always returns real value
    #print ("loop[",i,"]", loop[i])


    #print ("starte grad_1")
    grad_1=np.zeros((nt_hooft),dtype=complex)# dtype=np.float64)

    for i in range (omega_dim):
        for j in range (omega_dim):
            for k in range (num_loops+1):
                #print ("i=",i,"j=",j,"k=", k, "y", y[i+1,j+1,k], y[i+1,j+1,k]* grad_array_1[k])
                grad_1+= - LnJ[i]*y[i+1,j+1,k]*LnJ[j]* grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))

    """
    #print ("first grad_1", grad_1)
    grad_1=np.sum (np.array([[[(- LnJ[i]*y[i+1,j+1,k]*LnJ[j]* grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for j in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1,2))
    """

    """ old code
    for i in range (2,omega_dim):#(2,omega_size)
        for j in range (litte_omega_dim+1):
            for k in range (litte_omega_dim+1):
                grad_1+=2*LnJ[i]*z[i+1,j,k]*(grad_array_1[j]*loop[k]/(np.power(nt_hooft,(len(loop_list[j])+2)/2))+ loop[j]*grad_array_1[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2)))
    """

    #print ("starte grad_1 little_omega")

    for i in range (omega_dim):
        for j in range (litte_omega_dim+1):
            for k in range (j,litte_omega_dim+1):
                grad_1+=2*LnJ[i]*z[i+1,j,k]*(grad_array_1[j]*loop[k]/(np.power(nt_hooft,(len(loop_list[j])+2)/2))+ loop[j]*grad_array_1[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2)))

    for i in range (omega_dim):
        for k in range (num_loops+1):
            grad_1+=(-2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0+g4_coupling*y[i+1,10,k]+g4_coupling*y[i+1,15,k])*grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2)))
    grad_1=grad_1/8.0


    """
    grad_1+=np.sum (np.array([[[2*LnJ[i]*z[i+1,j,k]*(grad_array_1[j]*loop[k]/(np.power(nt_hooft,(len(loop_list[j])+2)/2))+ loop[j]*grad_array_1[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for j in range (litte_omega_dim+1)] for k in range (litte_omega_dim+1)]),axis=(0,1,2))
    grad_1+=np.sum (np.array([[(-2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0+g4_coupling*y[i+1,10,k]+g4_coupling*y[i+1,15,k])*grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1))
    grad_1=grad_1/8.0
    """
    grad_2=np.zeros((nt_hooft*nt_hooft),dtype=complex)

    #print ("started grad_2")
    #""" older version - slower but less memory
    for i in range (omega_dim):
        for j in range (omega_dim):
            for k in range (num_loops+1):
                grad_2+= - LnJ[i]*y[i+1,j+1,k]*LnJ[j]* grad_list_2[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))
    ##print ("grad_2 ", grad_2)
    #print ("finished first grad_2")
    """

    grad_2=np.sum (np.array([[[(- LnJ[i]*y[i+1,j+1,k]*LnJ[j]* grad_list_2[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for j in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1,2))
    """
    """ old code
    for i in range (2,omega_dim):#(2,omega_size)
        for j in range (litte_omega_dim+1):
            for k in range (litte_omega_dim+1):
                grad_2+=2*LnJ[i]*z[i+1,j,k]*(grad_list_2[j]*loop[k]/(np.power(nt_hooft, (len(loop_list[j])+2)/2))+ loop[j]*grad_list_2[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2)))

    ##print ("second grad_2 ", grad_2)
    """
    for i in range (omega_dim):
        for j in range (litte_omega_dim+1):
            for k in range (j,litte_omega_dim+1):
                grad_2+=2*LnJ[i]*z[i+1,j,k]*(grad_list_2[j]*loop[k]/(np.power(nt_hooft,(len(loop_list[j])+2)/2))+ loop[j]*grad_list_2[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2)))

    for i in range (omega_dim):
        for k in range (num_loops+1):
            grad_2+=(- 2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0+g4_coupling*y[i+1,10,k]+g4_coupling*y[i+1,15,k])*grad_list_2[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2)))
    grad_2=grad_2/8.0


    """
    #print ("starte grad_1 little_omega")
    grad_2+=np.sum (np.array([[[2*LnJ[i]*z[i+1,j,k]*(grad_list_2[j]*loop[k]/(np.power(nt_hooft,(len(loop_list[j])+2)/2))+ loop[j]*grad_list_2[k]/(np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for j in range (litte_omega_dim+1)] for k in range (litte_omega_dim+1)]),axis=(0,1,2))
    #grad_2+=np.sum (np.array([[(- 2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0)*grad_list_2[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1))
    grad_2+=np.sum (np.array([[(- 2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0+g4_coupling*y[i+1,10,k]+g4_coupling*y[i+1,15,k])*grad_list_2[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1))
    grad_2=grad_2/8.0
    #grad_2=grad_2/8.0 + grad_list_2[3]/ (2* np.power(nt_hooft, (len(loop_list[3])+2)/2))  + grad_list_2[5]/ (2* np.power(nt_hooft, (len(loop_list[5])+2)/2))
    #grad_2=grad_2.flatten()
    ##print ("third grad_2 ", grad_2)
    #print ("Concatenated derivative", format(np.concatenate((grad_1.real,grad_2.real),axis=0),'.6f'))
    """
    """
    print ("%%%%%%% Concatenated gradient")
    for x in np.concatenate((grad_1.real,grad_2.real),axis=0):
        print (format(x,'.8f'))
    """
    #""" most recent
    print ("%%%%%%% Concatenated gradient")
    for x in np.concatenate((grad_1,grad_2),axis=0):
        #print (format(x,'.8f'))
        print (x)
    #"""

    #print ("Concatenated derivative", np.around(np.concatenate((grad_1.real,grad_2.real),axis=0),decimals=6))
    return np.concatenate((grad_1.real,grad_2.real),axis=0)
    #x_init=np.concatenate ((eigen_init, m_2_init.flatten()),axis=0)

"""
Main program
"""

#global loop_list
#global numb_tuples_list
#global y
#global z

c=0.0
g_4=0.0
g_3=0.05
omega_length = 4
max_length = 2*omega_length-2

loop_list =[]                     # loop_list is a list of arrays, as arrays (loops) have different lengths
loop_list.append(np.array([]))

numb_tuples_list =[]
start=0
end=0
numb_tuples_list.append((start,end))

start1=timer()
for i in range (1,max_length+1):
    start=end+1
    loops_fixed_length = loops_of_length (i)
    num_fixed_length=np.ma.size(loops_fixed_length, axis=0)
    for j in range(num_fixed_length):
        loop_list.append(loops_fixed_length [j:j+1 ,:])
    end=start+num_fixed_length-1
    numb_tuples_list.append((start,end))
end1=timer()


#  Change (1,n) shape to (n,) for easier loop manipulation
for i in range(len(loop_list)):
    temp_loop = loop_list[i].T
    temp_len = np.ma.size(temp_loop, axis=0)
    loop_list[i] = np.reshape(temp_loop,(temp_len,))

i=0
for x in loop_list:
    print ("Loop", i,"=", x)
    i+=1

print (numb_tuples_list)
print ("Generating loops time", (end1-start1))


#  Building Omega matrix
omega_size = numb_tuples_list [omega_length][1]
print ("Omega size = ", omega_size)
max_size = numb_tuples_list [max_length][1]
print ("Total number of loops = ", max_size)
y=np.zeros((omega_size+1, omega_size+1, max_size+1))

print ("Joining loops and generating Omega ")

for i in range (1,omega_size+1):
    print ("starting row = ", i)
    for j in range (i,omega_size+1):
        loop_1 = loop_list [i]
        loop_2 = loop_list [j]
        #print ("loop_1", loop_1, "loop_2", loop_2    )
        for k in range (len(loop_1)):
            for l in range (len(loop_2)):
                if loop_1[k]==loop_2[l]:
                    loop_1_left = loop_1[0:k]
                    #print (loop_1_left)
                    loop_1_right= loop_1[k+1:len(loop_1)]
                    #print (loop_1_right)
                    loop_2_left = loop_2[0:l]
                    #print (loop_2_left)
                    loop_2_right= loop_2[l+1:len(loop_2)]
                    #print (loop_2_right)
                    #joined_loop = np.concatenate ((loop_1_right , loop_2_left,loop_2_right ,loop_1_left ))
                    joined_loop = np.concatenate ((loop_1_right , loop_1_left,loop_2_right ,loop_2_left ))
                    #print (str(loop_1), str(loop_2), (joined_loop))
                    start=numb_tuples_list [len(joined_loop)][0]
                    #print(start)
                    end=numb_tuples_list [len(joined_loop)][1]
                    #print (end)
                    for p in range(start,end+1):
                        if compare (loop_list[p],joined_loop):
                            #print ("identified loop")
                            y[i][j][p]+=1
                            if i != j : y[j][i][p]+=1

                            #print (y[i][j][p])

for i in range (1,omega_size+1):
    for j in range (1,omega_size+1):
        for k in range (max_size+1):
            if (y[i][j][k])!= 0. :
                print ("Loop", i,"=",loop_list[i],"joins with", "Loop", j,"=", loop_list[j], "into Loop", k,"=", loop_list[k], (y[i][j][k]), "times." )


# Start little omega

print ("Splitting loops and generating little omega ")
print ("Recall loops:")

i=0
for x in loop_list:
    print ("Loop", i,"=", x)
    i+=1


print ("Little omega")
#size to be fixed
little_omega_size = numb_tuples_list [omega_length-2][1]
print ("little_omega_size", little_omega_size)
#z=np.zeros ((omega_size+1,little_omega_size+1, little_omega_size+1))
z=np.zeros ((omega_size+1,omega_size+1, omega_size+1))

for i in range (3,omega_size+1):
    for k in range (len(loop_list[i])):
        for l in range (len(loop_list[i])):
            if k!=l :
                if loop_list[i][k]== loop_list[i][l]:
                    if k<l :
                        loop_inside=loop_list[i][k+1:l]
                        #print (i,loop_list[i], k,l, loop_inside)
                        #loop_outside_1 =
                        loop_outside=np.concatenate((loop_list[i][l+1:len(loop_list[i])],loop_list[i][0:k]))
                        #print (i,loop_list[i], k,l, loop_inside, loop_outside)
                        start=numb_tuples_list [len(loop_inside)][0]
                        end=numb_tuples_list [len(loop_inside)][1]
                        for p in range(start,end+1):
                            if compare (loop_list[p],loop_inside): loop_inside_index=p
                        start=numb_tuples_list [len(loop_outside)][0]
                        end=numb_tuples_list [len(loop_outside)][1]
                        for p in range(start,end+1):
                            if compare (loop_list[p],loop_outside):loop_outside_index=p
                        #z[i][loop_inside_index][loop_outside_index]+=1
                    else:
                        loop_inside=loop_inside=loop_list[i][l+1:k]
                        loop_outside=np.concatenate((loop_list[i][k+1:len(loop_list[i])],loop_list[i][0:l] ) )
                        #print (i,loop_list[i],k,l, loop_inside, loop_outside)
                        start=numb_tuples_list [len(loop_inside)][0]
                        end=numb_tuples_list [len(loop_inside)][1]
                        for p in range(start,end+1):
                            if compare (loop_list[p],loop_inside): loop_inside_index=p
                        start=numb_tuples_list [len(loop_outside)][0]
                        end=numb_tuples_list [len(loop_outside)][1]
                        for p in range(start,end+1):
                            if compare (loop_list[p],loop_outside):loop_outside_index=p
                    z[i][loop_inside_index][loop_outside_index]+=1


"""
for i in range (1,omega_size+1):
    for j in range (little_omega_size+1):
        for k in range (little_omega_size+1):
            if (z[i][j][k])!= 0. :
                print ("Loop", i,"=",loop_list[i],"breaks into", "Loop", j,"=", loop_list[j], "and Loop", k,"=", loop_list[k], (z[i][j][k]), "times." )
"""
# turn z into upper diagonal
for i in range (1,omega_size+1):
    for j in range (little_omega_size+1):
        for k in range (j+1,little_omega_size+1):
            z[i,j,k] = z[i,j,k]+ z[i,k,j]
            z[i,k,j] = 0


print("Symmetrized little omega")
for i in range (1,omega_size+1):
    for j in range (little_omega_size+1):
        for k in range (little_omega_size+1):
            if (z[i][j][k])!= 0. :
                print ("Loop", i,"=",loop_list[i],"breaks into", "Loop", j,"=", loop_list[j], "and Loop", k,"=", loop_list[k], (z[i][j][k]), "times." )








N = 5

loop=np.zeros ((max_size+1),dtype=complex)
omega=np.zeros ((omega_size,omega_size),dtype=complex)
#omega=np.diag(np.ones((omega_size))*(1.e-13))
#print ("Omega initial", omega )
little_omega=np.zeros ((omega_size),dtype=complex)
LnJ=np.zeros ((omega_size),dtype=complex)

print("Main Program")


# initial distribution of egenvalues for both matrices
#eigen_init = np.linspace(-0.5, 0.5, N)#
eigen_init=(np.random.rand(N) - np.ones(N)*0.5)*np.sqrt(N)
#eigen_init = np.linspace(-0.5, 0.5, N)*np.sqrt(N)
#eigen_init=np.zeros(N)
#alternating_1 =-1.0
#for i in range(N):
    #alternating_1*=-1.0
    #eigen_init[i]=alternating_1

"""
print ("Matrix 1 initial", eigen_init)
"""

# Matrix 2 has Pauli sigma_1 along diagonal Matrix

#m_2_init=np.diag(eigen_init)
m_2_init=(np.random.rand(N,N)-np.ones((N,N))*0.5)*np.sqrt(N)

#m_2_init=np.zeros((N,N))
#for i in range (0,N-1,2):
    #m_2_init[i,i+1]=1.
"""
print("Matrix 2 initial", m_2_init)
"""
#print (m_2_init.flatten())


x_init=np.concatenate ((eigen_init, m_2_init.flatten()),axis=0)

"""
print (x_init)
"""

#print ("Testing different matrices")

#x_init=[-1.0,0.,1.,-1.0,1.,2.,4.,0.,3.,5.,6.,1.]
#N=3

#effect_pot(x_init, omega_size,max_size, little_omega_size, N, c, g_3,g_4)
#effect_pot_grad(x_init, omega_size,max_size, little_omega_size, N, g_4)

start = timer()
#Energy = minimize (effect_pot, x_init, args=(omega_size,max_size ,little_omega_size, N, 0.0), method='nelder-mead', options={'disp': True, 'maxfev': 50000, 'maxiter': 50000})
Energy = minimize (effect_pot, x_init, args=(omega_size,max_size, little_omega_size, N, c, g_3,g_4), method='BFGS', jac=effect_pot_grad, options={'disp': True, 'maxiter': 5000,'gtol': np.sqrt(N*(N+1))*1e-16})
#Energy = minimize (effect_pot, x_init, args=(omega_size,max_size, little_omega_size, N, c, g_3,g_4), method='CG', jac=effect_pot_grad, options={'disp': True, 'maxiter': 5000,'gtol': np.sqrt(N*(N+1))*1e-16})

    #Energy = minimize (EffectPot, EigenInit, args=(OmegaSizeInit, N, g), method='BFGS', jac=Grad, options={'disp' : True, 'maxiter': 5000})

end = timer()
print((end - start), "sec in minimization")


"""
print ("Converged ?", Energy.success,
      'OmegaSize = ', omega_size,
      'N =', N,
      'Energy =', Energy.fun,
      'Tr(M_1^2) = ', round (loop[3],5),
      'Tr(M_2^2) = ', round (loop[5],5),
      "No. of iterations", Energy.nit)

print ("Master Field")
"""


matrix_1_final = np.diag(Energy.x[0:N])

##print ("Matrix 1")
##print (np.around(matrix_1_final,decimals=5))


temp_matrix_2_final = np.reshape (Energy.x[N:N**2+N], (N,N))
real_matrix_2_final = np.triu(temp_matrix_2_final)
real_matrix_2_final = real_matrix_2_final+real_matrix_2_final.T-np.diag(np.diag(temp_matrix_2_final))
imag_matrix_2_final = np.tril(temp_matrix_2_final)
imag_matrix_2_final = imag_matrix_2_final-imag_matrix_2_final.T
matrix_2_final=real_matrix_2_final+imag_matrix_2_final*1.j

##print ("Matrix 2")
##print (np.around(matrix_2_final,decimals=5))

matrices_array_final =np.zeros((2,N,N),dtype=complex)
matrices_array_final[0] =matrix_1_final
matrices_array_final[1] =matrix_2_final

for i in range (1,max_size+1):
    loop_matrix=matrices_array_final[loop_list[i][0]-1]
    #print (loop_list[i], loop_list[i][0]-1, len(loop_list[i]))
    #print (loop_matrix)
    for k in range(1,len(loop_list[i])):
        #print (k)
        #loop_matrix=loop_matrix @ matrices_array[loop_list[i][k]-1]
        loop_matrix=np.dot(loop_matrix,matrices_array_final[loop_list[i][k]-1])
    #print("after k loop, loop matrix", loop_matrix)
    loop[i]=np.trace(loop_matrix) / ( np.power(N, (len(loop_list[i])+2)/2)) #note: not declared as complex; always returns real value
    #print ("loop[",i,"]", loop[i])
loop[0]=1.

print ("Energy =", Energy.fun)
for i in range (max_size+1):
    print ("Loop,", i,",=,",loop_list[i], ",has value,", format(loop[i].real, '.6f'), ",imaginary part,", format(loop[i].imag, '.6f'))#round (loop[i].real,5)
for i in range (omega_size):
    print ("SD,",loop_list[i+1],",i,", i+1,",=,",little_omega[i])#round (loop[i].real,5)

A=np.zeros((omega_size,omega_size),dtype=complex)
for i in range (omega_size):
    for j in range (little_omega_size):
        for k in range (little_omega_size+1):
        #A[i,j]-=np.sum (np.array([z[i+1,j+1,k]*loop[k] for k in range (little_omega_size+1)]))    ##axis?
        #A[i,j]-=np.sum (np.array([z[i+1,k,j+1]*loop[k] for k in range (little_omega_size+1)]))
            A[i,j]+=z[i+1,j+1,k]*loop[k]    ##axis?
            A[i,j]+=z[i+1,k,j+1]*loop[k]
    for j in range (omega_size):
        A[i,j]-=(y[i+1,3,j+1]/2.0 +y[i+1,5,j+1]/2.0 - c*y[i+1,4,j+1]+g_3*y[i+1,6,j+1]/3.0+g_3*y[i+1,9,j+1]/3.0)

omega_inv=linalg.inv(omega)


print ("c =",c,",", "g_3 =", g_3, ",","g_4=", g_4 )
print ("No of loops =",max_size, ",","lmax =",omega_length, ",","Omega is", omega_size,"x", omega_size, "matrix")
print ( "N =", N, ",","No of master variables = ", N*(N+1))
print ("Fluctuations spectrum")
#print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, A.T, omega_inv, A])))))
print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, A.T, omega_inv, A])).real)))
#print ("Fluctuations spectrum -  matrix A")
#print (np.sort(linalg.eigvals(A).real))

#print ("Old fashioned matrix multiplication")
#print (np.sort(np.sqrt(linalg.eigvals(np.dot(np.dot(np.dot(omega, A.T), omega_inv), A)).real)))

#print ("Fluctuations spectrum - 2")
#print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, A.T, omega_inv, A])))))
#print (np.sort(np.sqrt(linalg.eigvals(multi_dot([A, omega, np.transpose(A), omega_inv])).real)))
#print (np.sort(np.sqrt(linalg.eigvals(multi_dot([A, omega, np.transpose(A), omega_inv])*np.linalg.det(omega)).real)))

#print ("no sqrt")
#print (np.sort(linalg.eigvals(multi_dot([A, omega, np.transpose(A), omega_inv])).real))



#print ("At A eigenvalues")
#print (np.sort(np.sqrt(linalg.eigvals(multi_dot([A,A.T])).real)))

#print ("Omega")
#print (omega.real)

#print ("LnJ")
#print(LnJ)

#print ("A eigenvalues")
#print (np.sort(linalg.eigvals(A)).real)

#print (A.real)

#print ("A transpose eigenvalues")
#print (np.sort(linalg.eigvals(A.T)).real)

#print ("Omega eigenvalues")
#print (np.sort(linalg.eigvals(omega)).real)

#print ("Omega inverse eigenvalues")
#print (np.sort(linalg.eigvals(omega_inv)).real)


""" second derivative of full potential

little_omega_2 = np.zeros ((omega_size,omega_size,omega_size),dtype=complex)
for i in range (omega_size):
    for j in range (omega_size):
        for k in range (omega_size):
            print (z[i+1][k+1][j+1]+z[i+1][j+1][k+1])
"""

"""
#little_omega_2 = np.zeros ((omega_size,omega_size,omega_size),dtype=complex)
#little_omega_2 = np.array ([[[ (z[i+1,k+1,j+1]+z[i+1,j+1,k+1]) for i in range (omega_size)] for j in range (omega_size)] for k in range (omega_size)])
print (little_omega_2.shape)
print (little_omega_2)
"""

V_2=multi_dot([A.T, omega_inv, A])
"""
print ("V_2 contribution 1")
print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, V_2])).real)))
"""

V_2+=np.sum(np.array ([[[ (z[i+1,k+1,j+1]+z[i+1,j+1,k+1])*LnJ[i] for i in range (omega_size)] for j in range (omega_size)] for k in range (omega_size)]),axis=2)

"""
print ("V_2 contribution 2")
print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, V_2])).real)))
"""


Omega_deriv = np.zeros((omega_size, omega_size), dtype=complex)
for i in range (omega_size):
    for k in range (omega_size):
        Omega_deriv[i,k]=np.sum(np.array([LnJ[j]*y[i+1,j+1,k] for j in range (omega_size)]))

V_2+=multi_dot([Omega_deriv.T, omega_inv, Omega_deriv])

"""
print ("V_2 contribution 3")
print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, V_2])).real)))
"""

V_2+= -2*multi_dot([A.T, omega_inv, Omega_deriv])


print ("V_2 total contribution")
print (np.sort(np.sqrt(linalg.eigvals(multi_dot([omega, V_2])).real)))


#print (Omega_deriv.shape)
#print (Omega_deriv)

print ("Master Field")

for y in Energy.x :
    print (y)



print (Energy.x)

with open('output.npy', 'wb') as f:
    np.save(f,c)
    np.save(f,g_3)
    np.save(f,g_4)
    np.save(f,omega_length)
    np.save(f,N)
    np.save (f, Energy.x)

with open('output.npy', 'rb') as f:
    loaded_c=np.load(f)
    loaded_g_3=np.load(f)
    loaded_g_4=np.load(f)
    loaded_omega_length=np.load(f)
    loaded_N=np.load(f)
    loaded_master_field = np.load(f)


print ("Info extracted from file")
print (loaded_c)
print (loaded_g_3)
print (loaded_g_4)
print (loaded_omega_length)
print (loaded_N)
print ("Extracted Master Field")
print (loaded_master_field)


for y in loaded_master_field :
    print (y)


#V_2+=2*np.sum (np.array([[[ (z(i+1,k+1,j+1)+z(i+1,j+1,k+1))*LnJ(i) for i in range (omega_size)] for j in range (omega_size)] for k in range (omega_size)]), axis = 0)





"""
for i in range (omega_size):
    for j in range (num_loops+1):k in range (num_loops+1)
##print ("second grad_1 ",  grad_1 )

grad_1+=np.sum (np.array([[(-2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0)*grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1))
"""

#print ("eigenvalues of the hessian")

#for i in range ( len(linalg.eigvals(linalg.inv(Energy.hess_inv)))):
#    print (linalg.eigvals(linalg.inv(Energy.hess_inv))[i])
# Out:
# starting loops of length  1
# starting loops of length  2
# starting with 1 [2]s
# starting loops of length  3
# starting with 1 [2]s
# starting with 2 [2]s
# starting loops of length  4
# starting with 1 [2]s
# starting with 2 [2]s
# starting with 3 [2]s
# starting loops of length  5
# starting with 1 [2]s
# starting with 2 [2]s
# starting with 3 [2]s
# starting with 4 [2]s
# starting loops of length  6
# starting with 1 [2]s
# starting with 2 [2]s
# starting with 3 [2]s
# starting with 4 [2]s
# starting with 5 [2]s
# Loop 0 = []
# Loop 1 = [1]
# Loop 2 = [2]
# Loop 3 = [1 1]
# Loop 4 = [1 2]
# Loop 5 = [2 2]
# Loop 6 = [1 1 1]
# Loop 7 = [1 1 2]
# Loop 8 = [1 2 2]
# Loop 9 = [2 2 2]
# Loop 10 = [1 1 1 1]
# Loop 11 = [1 1 1 2]
# Loop 12 = [1 1 2 2]
# Loop 13 = [1 2 1 2]
# Loop 14 = [1 2 2 2]
# Loop 15 = [2 2 2 2]
# Loop 16 = [1 1 1 1 1]
# Loop 17 = [1 1 1 1 2]
# Loop 18 = [1 1 1 2 2]
# Loop 19 = [1 1 2 1 2]
# Loop 20 = [1 1 2 2 2]
# Loop 21 = [1 2 1 2 2]
# Loop 22 = [1 2 2 2 2]
# Loop 23 = [2 2 2 2 2]
# Loop 24 = [1 1 1 1 1 1]
# Loop 25 = [1 1 1 1 1 2]
# Loop 26 = [1 1 1 1 2 2]
# Loop 27 = [1 1 1 2 1 2]
# Loop 28 = [1 1 2 1 1 2]
# Loop 29 = [1 1 1 2 2 2]
# Loop 30 = [1 1 2 1 2 2]
# Loop 31 = [1 1 2 2 1 2]
# Loop 32 = [1 2 1 2 1 2]
# Loop 33 = [1 1 2 2 2 2]
# Loop 34 = [1 2 1 2 2 2]
# Loop 35 = [1 2 2 1 2 2]
# Loop 36 = [1 2 2 2 2 2]
# Loop 37 = [2 2 2 2 2 2]
# [(0, 0), (1, 2), (3, 5), (6, 9), (10, 15), (16, 23), (24, 37)]
# Generating loops time 0.032672079000008125
# Omega size =  15
# Total number of loops =  37
# Joining loops and generating Omega
# starting row =  1
# starting row =  2
# starting row =  3
# starting row =  4
# starting row =  5
# starting row =  6
# starting row =  7
# starting row =  8
# starting row =  9
# starting row =  10
# starting row =  11
# starting row =  12
# starting row =  13
# starting row =  14
# starting row =  15
# Loop 1 = [1] joins with Loop 1 = [1] into Loop 0 = [] 1.0 times.
# Loop 1 = [1] joins with Loop 3 = [1 1] into Loop 1 = [1] 2.0 times.
# Loop 1 = [1] joins with Loop 4 = [1 2] into Loop 2 = [2] 1.0 times.
# Loop 1 = [1] joins with Loop 6 = [1 1 1] into Loop 3 = [1 1] 3.0 times.
# Loop 1 = [1] joins with Loop 7 = [1 1 2] into Loop 4 = [1 2] 2.0 times.
# Loop 1 = [1] joins with Loop 8 = [1 2 2] into Loop 5 = [2 2] 1.0 times.
# Loop 1 = [1] joins with Loop 10 = [1 1 1 1] into Loop 6 = [1 1 1] 4.0 times.
# Loop 1 = [1] joins with Loop 11 = [1 1 1 2] into Loop 7 = [1 1 2] 3.0 times.
# Loop 1 = [1] joins with Loop 12 = [1 1 2 2] into Loop 8 = [1 2 2] 2.0 times.
# Loop 1 = [1] joins with Loop 13 = [1 2 1 2] into Loop 8 = [1 2 2] 2.0 times.
# Loop 1 = [1] joins with Loop 14 = [1 2 2 2] into Loop 9 = [2 2 2] 1.0 times.
# Loop 2 = [2] joins with Loop 2 = [2] into Loop 0 = [] 1.0 times.
# Loop 2 = [2] joins with Loop 4 = [1 2] into Loop 1 = [1] 1.0 times.
# Loop 2 = [2] joins with Loop 5 = [2 2] into Loop 2 = [2] 2.0 times.
# Loop 2 = [2] joins with Loop 7 = [1 1 2] into Loop 3 = [1 1] 1.0 times.
# Loop 2 = [2] joins with Loop 8 = [1 2 2] into Loop 4 = [1 2] 2.0 times.
# Loop 2 = [2] joins with Loop 9 = [2 2 2] into Loop 5 = [2 2] 3.0 times.
# Loop 2 = [2] joins with Loop 11 = [1 1 1 2] into Loop 6 = [1 1 1] 1.0 times.
# Loop 2 = [2] joins with Loop 12 = [1 1 2 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 2 = [2] joins with Loop 13 = [1 2 1 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 2 = [2] joins with Loop 14 = [1 2 2 2] into Loop 8 = [1 2 2] 3.0 times.
# Loop 2 = [2] joins with Loop 15 = [2 2 2 2] into Loop 9 = [2 2 2] 4.0 times.
# Loop 3 = [1 1] joins with Loop 1 = [1] into Loop 1 = [1] 2.0 times.
# Loop 3 = [1 1] joins with Loop 3 = [1 1] into Loop 3 = [1 1] 4.0 times.
# Loop 3 = [1 1] joins with Loop 4 = [1 2] into Loop 4 = [1 2] 2.0 times.
# Loop 3 = [1 1] joins with Loop 6 = [1 1 1] into Loop 6 = [1 1 1] 6.0 times.
# Loop 3 = [1 1] joins with Loop 7 = [1 1 2] into Loop 7 = [1 1 2] 4.0 times.
# Loop 3 = [1 1] joins with Loop 8 = [1 2 2] into Loop 8 = [1 2 2] 2.0 times.
# Loop 3 = [1 1] joins with Loop 10 = [1 1 1 1] into Loop 10 = [1 1 1 1] 8.0 times.
# Loop 3 = [1 1] joins with Loop 11 = [1 1 1 2] into Loop 11 = [1 1 1 2] 6.0 times.
# Loop 3 = [1 1] joins with Loop 12 = [1 1 2 2] into Loop 12 = [1 1 2 2] 4.0 times.
# Loop 3 = [1 1] joins with Loop 13 = [1 2 1 2] into Loop 13 = [1 2 1 2] 4.0 times.
# Loop 3 = [1 1] joins with Loop 14 = [1 2 2 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 1 = [1] into Loop 2 = [2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 2 = [2] into Loop 1 = [1] 1.0 times.
# Loop 4 = [1 2] joins with Loop 3 = [1 1] into Loop 4 = [1 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 4 = [1 2] into Loop 3 = [1 1] 1.0 times.
# Loop 4 = [1 2] joins with Loop 4 = [1 2] into Loop 5 = [2 2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 5 = [2 2] into Loop 4 = [1 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 6 = [1 1 1] into Loop 7 = [1 1 2] 3.0 times.
# Loop 4 = [1 2] joins with Loop 7 = [1 1 2] into Loop 6 = [1 1 1] 1.0 times.
# Loop 4 = [1 2] joins with Loop 7 = [1 1 2] into Loop 8 = [1 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 8 = [1 2 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 8 = [1 2 2] into Loop 9 = [2 2 2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 9 = [2 2 2] into Loop 8 = [1 2 2] 3.0 times.
# Loop 4 = [1 2] joins with Loop 10 = [1 1 1 1] into Loop 11 = [1 1 1 2] 4.0 times.
# Loop 4 = [1 2] joins with Loop 11 = [1 1 1 2] into Loop 10 = [1 1 1 1] 1.0 times.
# Loop 4 = [1 2] joins with Loop 11 = [1 1 1 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 11 = [1 1 1 2] into Loop 13 = [1 2 1 2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 12 = [1 1 2 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 12 = [1 1 2 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 13 = [1 2 1 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 13 = [1 2 1 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 14 = [1 2 2 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 4 = [1 2] joins with Loop 14 = [1 2 2 2] into Loop 13 = [1 2 1 2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 14 = [1 2 2 2] into Loop 15 = [2 2 2 2] 1.0 times.
# Loop 4 = [1 2] joins with Loop 15 = [2 2 2 2] into Loop 14 = [1 2 2 2] 4.0 times.
# Loop 5 = [2 2] joins with Loop 2 = [2] into Loop 2 = [2] 2.0 times.
# Loop 5 = [2 2] joins with Loop 4 = [1 2] into Loop 4 = [1 2] 2.0 times.
# Loop 5 = [2 2] joins with Loop 5 = [2 2] into Loop 5 = [2 2] 4.0 times.
# Loop 5 = [2 2] joins with Loop 7 = [1 1 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 5 = [2 2] joins with Loop 8 = [1 2 2] into Loop 8 = [1 2 2] 4.0 times.
# Loop 5 = [2 2] joins with Loop 9 = [2 2 2] into Loop 9 = [2 2 2] 6.0 times.
# Loop 5 = [2 2] joins with Loop 11 = [1 1 1 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 5 = [2 2] joins with Loop 12 = [1 1 2 2] into Loop 12 = [1 1 2 2] 4.0 times.
# Loop 5 = [2 2] joins with Loop 13 = [1 2 1 2] into Loop 13 = [1 2 1 2] 4.0 times.
# Loop 5 = [2 2] joins with Loop 14 = [1 2 2 2] into Loop 14 = [1 2 2 2] 6.0 times.
# Loop 5 = [2 2] joins with Loop 15 = [2 2 2 2] into Loop 15 = [2 2 2 2] 8.0 times.
# Loop 6 = [1 1 1] joins with Loop 1 = [1] into Loop 3 = [1 1] 3.0 times.
# Loop 6 = [1 1 1] joins with Loop 3 = [1 1] into Loop 6 = [1 1 1] 6.0 times.
# Loop 6 = [1 1 1] joins with Loop 4 = [1 2] into Loop 7 = [1 1 2] 3.0 times.
# Loop 6 = [1 1 1] joins with Loop 6 = [1 1 1] into Loop 10 = [1 1 1 1] 9.0 times.
# Loop 6 = [1 1 1] joins with Loop 7 = [1 1 2] into Loop 11 = [1 1 1 2] 6.0 times.
# Loop 6 = [1 1 1] joins with Loop 8 = [1 2 2] into Loop 12 = [1 1 2 2] 3.0 times.
# Loop 6 = [1 1 1] joins with Loop 10 = [1 1 1 1] into Loop 16 = [1 1 1 1 1] 12.0 times.
# Loop 6 = [1 1 1] joins with Loop 11 = [1 1 1 2] into Loop 17 = [1 1 1 1 2] 9.0 times.
# Loop 6 = [1 1 1] joins with Loop 12 = [1 1 2 2] into Loop 18 = [1 1 1 2 2] 6.0 times.
# Loop 6 = [1 1 1] joins with Loop 13 = [1 2 1 2] into Loop 19 = [1 1 2 1 2] 6.0 times.
# Loop 6 = [1 1 1] joins with Loop 14 = [1 2 2 2] into Loop 20 = [1 1 2 2 2] 3.0 times.
# Loop 7 = [1 1 2] joins with Loop 1 = [1] into Loop 4 = [1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 2 = [2] into Loop 3 = [1 1] 1.0 times.
# Loop 7 = [1 1 2] joins with Loop 3 = [1 1] into Loop 7 = [1 1 2] 4.0 times.
# Loop 7 = [1 1 2] joins with Loop 4 = [1 2] into Loop 6 = [1 1 1] 1.0 times.
# Loop 7 = [1 1 2] joins with Loop 4 = [1 2] into Loop 8 = [1 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 5 = [2 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 6 = [1 1 1] into Loop 11 = [1 1 1 2] 6.0 times.
# Loop 7 = [1 1 2] joins with Loop 7 = [1 1 2] into Loop 10 = [1 1 1 1] 1.0 times.
# Loop 7 = [1 1 2] joins with Loop 7 = [1 1 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 7 = [1 1 2] into Loop 13 = [1 2 1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 8 = [1 2 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 8 = [1 2 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 9 = [2 2 2] into Loop 12 = [1 1 2 2] 3.0 times.
# Loop 7 = [1 1 2] joins with Loop 10 = [1 1 1 1] into Loop 17 = [1 1 1 1 2] 8.0 times.
# Loop 7 = [1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 16 = [1 1 1 1 1] 1.0 times.
# Loop 7 = [1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 19 = [1 1 2 1 2] 4.0 times.
# Loop 7 = [1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 21 = [1 2 1 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 21 = [1 2 1 2 2] 4.0 times.
# Loop 7 = [1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 19 = [1 1 2 1 2] 1.0 times.
# Loop 7 = [1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 7 = [1 1 2] joins with Loop 15 = [2 2 2 2] into Loop 20 = [1 1 2 2 2] 4.0 times.
# Loop 8 = [1 2 2] joins with Loop 1 = [1] into Loop 5 = [2 2] 1.0 times.
# Loop 8 = [1 2 2] joins with Loop 2 = [2] into Loop 4 = [1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 3 = [1 1] into Loop 8 = [1 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 4 = [1 2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 4 = [1 2] into Loop 9 = [2 2 2] 1.0 times.
# Loop 8 = [1 2 2] joins with Loop 5 = [2 2] into Loop 8 = [1 2 2] 4.0 times.
# Loop 8 = [1 2 2] joins with Loop 6 = [1 1 1] into Loop 12 = [1 1 2 2] 3.0 times.
# Loop 8 = [1 2 2] joins with Loop 7 = [1 1 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 7 = [1 1 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 8 = [1 2 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 8 = [1 2 2] into Loop 13 = [1 2 1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 8 = [1 2 2] into Loop 15 = [2 2 2 2] 1.0 times.
# Loop 8 = [1 2 2] joins with Loop 9 = [2 2 2] into Loop 14 = [1 2 2 2] 6.0 times.
# Loop 8 = [1 2 2] joins with Loop 10 = [1 1 1 1] into Loop 18 = [1 1 1 2 2] 4.0 times.
# Loop 8 = [1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 21 = [1 2 1 2 2] 1.0 times.
# Loop 8 = [1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 19 = [1 1 2 1 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 13 = [1 2 1 2] into Loop 19 = [1 1 2 1 2] 4.0 times.
# Loop 8 = [1 2 2] joins with Loop 13 = [1 2 1 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 8 = [1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 21 = [1 2 1 2 2] 4.0 times.
# Loop 8 = [1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 23 = [2 2 2 2 2] 1.0 times.
# Loop 8 = [1 2 2] joins with Loop 15 = [2 2 2 2] into Loop 22 = [1 2 2 2 2] 8.0 times.
# Loop 9 = [2 2 2] joins with Loop 2 = [2] into Loop 5 = [2 2] 3.0 times.
# Loop 9 = [2 2 2] joins with Loop 4 = [1 2] into Loop 8 = [1 2 2] 3.0 times.
# Loop 9 = [2 2 2] joins with Loop 5 = [2 2] into Loop 9 = [2 2 2] 6.0 times.
# Loop 9 = [2 2 2] joins with Loop 7 = [1 1 2] into Loop 12 = [1 1 2 2] 3.0 times.
# Loop 9 = [2 2 2] joins with Loop 8 = [1 2 2] into Loop 14 = [1 2 2 2] 6.0 times.
# Loop 9 = [2 2 2] joins with Loop 9 = [2 2 2] into Loop 15 = [2 2 2 2] 9.0 times.
# Loop 9 = [2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 18 = [1 1 1 2 2] 3.0 times.
# Loop 9 = [2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 20 = [1 1 2 2 2] 6.0 times.
# Loop 9 = [2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 21 = [1 2 1 2 2] 6.0 times.
# Loop 9 = [2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 22 = [1 2 2 2 2] 9.0 times.
# Loop 9 = [2 2 2] joins with Loop 15 = [2 2 2 2] into Loop 23 = [2 2 2 2 2] 12.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 1 = [1] into Loop 6 = [1 1 1] 4.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 3 = [1 1] into Loop 10 = [1 1 1 1] 8.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 4 = [1 2] into Loop 11 = [1 1 1 2] 4.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 6 = [1 1 1] into Loop 16 = [1 1 1 1 1] 12.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 7 = [1 1 2] into Loop 17 = [1 1 1 1 2] 8.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 8 = [1 2 2] into Loop 18 = [1 1 1 2 2] 4.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 10 = [1 1 1 1] into Loop 24 = [1 1 1 1 1 1] 16.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 11 = [1 1 1 2] into Loop 25 = [1 1 1 1 1 2] 12.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 12 = [1 1 2 2] into Loop 26 = [1 1 1 1 2 2] 8.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 13 = [1 2 1 2] into Loop 27 = [1 1 1 2 1 2] 8.0 times.
# Loop 10 = [1 1 1 1] joins with Loop 14 = [1 2 2 2] into Loop 29 = [1 1 1 2 2 2] 4.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 1 = [1] into Loop 7 = [1 1 2] 3.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 2 = [2] into Loop 6 = [1 1 1] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 3 = [1 1] into Loop 11 = [1 1 1 2] 6.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 4 = [1 2] into Loop 10 = [1 1 1 1] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 4 = [1 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 4 = [1 2] into Loop 13 = [1 2 1 2] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 5 = [2 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 6 = [1 1 1] into Loop 17 = [1 1 1 1 2] 9.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 7 = [1 1 2] into Loop 16 = [1 1 1 1 1] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 7 = [1 1 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 7 = [1 1 2] into Loop 19 = [1 1 2 1 2] 4.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 8 = [1 2 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 8 = [1 2 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 8 = [1 2 2] into Loop 21 = [1 2 1 2 2] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 9 = [2 2 2] into Loop 18 = [1 1 1 2 2] 3.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 10 = [1 1 1 1] into Loop 25 = [1 1 1 1 1 2] 12.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 24 = [1 1 1 1 1 1] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 26 = [1 1 1 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 27 = [1 1 1 2 1 2] 4.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 11 = [1 1 1 2] into Loop 28 = [1 1 2 1 1 2] 3.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 25 = [1 1 1 1 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 29 = [1 1 1 2 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 12 = [1 1 2 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 25 = [1 1 1 1 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 13 = [1 2 1 2] into Loop 32 = [1 2 1 2 1 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 26 = [1 1 1 1 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 27 = [1 1 1 2 1 2] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 33 = [1 1 2 2 2 2] 2.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 14 = [1 2 2 2] into Loop 34 = [1 2 1 2 2 2] 1.0 times.
# Loop 11 = [1 1 1 2] joins with Loop 15 = [2 2 2 2] into Loop 29 = [1 1 1 2 2 2] 4.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 1 = [1] into Loop 8 = [1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 2 = [2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 3 = [1 1] into Loop 12 = [1 1 2 2] 4.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 4 = [1 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 4 = [1 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 5 = [2 2] into Loop 12 = [1 1 2 2] 4.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 6 = [1 1 1] into Loop 18 = [1 1 1 2 2] 6.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 7 = [1 1 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 7 = [1 1 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 7 = [1 1 2] into Loop 21 = [1 2 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 8 = [1 2 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 8 = [1 2 2] into Loop 19 = [1 1 2 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 8 = [1 2 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 9 = [2 2 2] into Loop 20 = [1 1 2 2 2] 6.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 10 = [1 1 1 1] into Loop 26 = [1 1 1 1 2 2] 8.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 25 = [1 1 1 1 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 29 = [1 1 1 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 11 = [1 1 1 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 26 = [1 1 1 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 28 = [1 1 2 1 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 33 = [1 1 2 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 12 = [1 1 2 2] into Loop 35 = [1 2 2 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 13 = [1 2 1 2] into Loop 27 = [1 1 1 2 1 2] 4.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 13 = [1 2 1 2] into Loop 34 = [1 2 1 2 2 2] 4.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 29 = [1 1 1 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 14 = [1 2 2 2] into Loop 36 = [1 2 2 2 2 2] 2.0 times.
# Loop 12 = [1 1 2 2] joins with Loop 15 = [2 2 2 2] into Loop 33 = [1 1 2 2 2 2] 8.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 1 = [1] into Loop 8 = [1 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 2 = [2] into Loop 7 = [1 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 3 = [1 1] into Loop 13 = [1 2 1 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 4 = [1 2] into Loop 11 = [1 1 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 4 = [1 2] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 5 = [2 2] into Loop 13 = [1 2 1 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 6 = [1 1 1] into Loop 19 = [1 1 2 1 2] 6.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 7 = [1 1 2] into Loop 17 = [1 1 1 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 7 = [1 1 2] into Loop 21 = [1 2 1 2 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 8 = [1 2 2] into Loop 19 = [1 1 2 1 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 8 = [1 2 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 9 = [2 2 2] into Loop 21 = [1 2 1 2 2] 6.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 10 = [1 1 1 1] into Loop 27 = [1 1 1 2 1 2] 8.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 11 = [1 1 1 2] into Loop 25 = [1 1 1 1 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 11 = [1 1 1 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 11 = [1 1 1 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 11 = [1 1 1 2] into Loop 32 = [1 2 1 2 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 12 = [1 1 2 2] into Loop 27 = [1 1 1 2 1 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 12 = [1 1 2 2] into Loop 34 = [1 2 1 2 2 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 13 = [1 2 1 2] into Loop 28 = [1 1 2 1 1 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 13 = [1 2 1 2] into Loop 35 = [1 2 2 1 2 2] 4.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 14 = [1 2 2 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 14 = [1 2 2 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 14 = [1 2 2 2] into Loop 32 = [1 2 1 2 1 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 14 = [1 2 2 2] into Loop 36 = [1 2 2 2 2 2] 2.0 times.
# Loop 13 = [1 2 1 2] joins with Loop 15 = [2 2 2 2] into Loop 34 = [1 2 1 2 2 2] 8.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 1 = [1] into Loop 9 = [2 2 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 2 = [2] into Loop 8 = [1 2 2] 3.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 3 = [1 1] into Loop 14 = [1 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 4 = [1 2] into Loop 12 = [1 1 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 4 = [1 2] into Loop 13 = [1 2 1 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 4 = [1 2] into Loop 15 = [2 2 2 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 5 = [2 2] into Loop 14 = [1 2 2 2] 6.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 6 = [1 1 1] into Loop 20 = [1 1 2 2 2] 3.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 7 = [1 1 2] into Loop 18 = [1 1 1 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 7 = [1 1 2] into Loop 19 = [1 1 2 1 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 7 = [1 1 2] into Loop 22 = [1 2 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 8 = [1 2 2] into Loop 20 = [1 1 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 8 = [1 2 2] into Loop 21 = [1 2 1 2 2] 4.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 8 = [1 2 2] into Loop 23 = [2 2 2 2 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 9 = [2 2 2] into Loop 22 = [1 2 2 2 2] 9.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 10 = [1 1 1 1] into Loop 29 = [1 1 1 2 2 2] 4.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 26 = [1 1 1 1 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 27 = [1 1 1 2 1 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 33 = [1 1 2 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 34 = [1 2 1 2 2 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 29 = [1 1 1 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 36 = [1 2 2 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 30 = [1 1 2 1 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 31 = [1 1 2 2 1 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 32 = [1 2 1 2 1 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 36 = [1 2 2 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 33 = [1 1 2 2 2 2] 2.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 34 = [1 2 1 2 2 2] 4.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 35 = [1 2 2 1 2 2] 3.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 37 = [2 2 2 2 2 2] 1.0 times.
# Loop 14 = [1 2 2 2] joins with Loop 15 = [2 2 2 2] into Loop 36 = [1 2 2 2 2 2] 12.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 2 = [2] into Loop 9 = [2 2 2] 4.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 4 = [1 2] into Loop 14 = [1 2 2 2] 4.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 5 = [2 2] into Loop 15 = [2 2 2 2] 8.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 7 = [1 1 2] into Loop 20 = [1 1 2 2 2] 4.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 8 = [1 2 2] into Loop 22 = [1 2 2 2 2] 8.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 9 = [2 2 2] into Loop 23 = [2 2 2 2 2] 12.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 11 = [1 1 1 2] into Loop 29 = [1 1 1 2 2 2] 4.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 12 = [1 1 2 2] into Loop 33 = [1 1 2 2 2 2] 8.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 13 = [1 2 1 2] into Loop 34 = [1 2 1 2 2 2] 8.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 14 = [1 2 2 2] into Loop 36 = [1 2 2 2 2 2] 12.0 times.
# Loop 15 = [2 2 2 2] joins with Loop 15 = [2 2 2 2] into Loop 37 = [2 2 2 2 2 2] 16.0 times.
# Splitting loops and generating little omega
# Recall loops:
# Loop 0 = []
# Loop 1 = [1]
# Loop 2 = [2]
# Loop 3 = [1 1]
# Loop 4 = [1 2]
# Loop 5 = [2 2]
# Loop 6 = [1 1 1]
# Loop 7 = [1 1 2]
# Loop 8 = [1 2 2]
# Loop 9 = [2 2 2]
# Loop 10 = [1 1 1 1]
# Loop 11 = [1 1 1 2]
# Loop 12 = [1 1 2 2]
# Loop 13 = [1 2 1 2]
# Loop 14 = [1 2 2 2]
# Loop 15 = [2 2 2 2]
# Loop 16 = [1 1 1 1 1]
# Loop 17 = [1 1 1 1 2]
# Loop 18 = [1 1 1 2 2]
# Loop 19 = [1 1 2 1 2]
# Loop 20 = [1 1 2 2 2]
# Loop 21 = [1 2 1 2 2]
# Loop 22 = [1 2 2 2 2]
# Loop 23 = [2 2 2 2 2]
# Loop 24 = [1 1 1 1 1 1]
# Loop 25 = [1 1 1 1 1 2]
# Loop 26 = [1 1 1 1 2 2]
# Loop 27 = [1 1 1 2 1 2]
# Loop 28 = [1 1 2 1 1 2]
# Loop 29 = [1 1 1 2 2 2]
# Loop 30 = [1 1 2 1 2 2]
# Loop 31 = [1 1 2 2 1 2]
# Loop 32 = [1 2 1 2 1 2]
# Loop 33 = [1 1 2 2 2 2]
# Loop 34 = [1 2 1 2 2 2]
# Loop 35 = [1 2 2 1 2 2]
# Loop 36 = [1 2 2 2 2 2]
# Loop 37 = [2 2 2 2 2 2]
# Little omega
# little_omega_size 5
# Symmetrized little omega
# Loop 3 = [1 1] breaks into Loop 0 = [] and Loop 0 = [] 2.0 times.
# Loop 5 = [2 2] breaks into Loop 0 = [] and Loop 0 = [] 2.0 times.
# Loop 6 = [1 1 1] breaks into Loop 0 = [] and Loop 1 = [1] 6.0 times.
# Loop 7 = [1 1 2] breaks into Loop 0 = [] and Loop 2 = [2] 2.0 times.
# Loop 8 = [1 2 2] breaks into Loop 0 = [] and Loop 1 = [1] 2.0 times.
# Loop 9 = [2 2 2] breaks into Loop 0 = [] and Loop 2 = [2] 6.0 times.
# Loop 10 = [1 1 1 1] breaks into Loop 0 = [] and Loop 3 = [1 1] 8.0 times.
# Loop 10 = [1 1 1 1] breaks into Loop 1 = [1] and Loop 1 = [1] 4.0 times.
# Loop 11 = [1 1 1 2] breaks into Loop 0 = [] and Loop 4 = [1 2] 4.0 times.
# Loop 11 = [1 1 1 2] breaks into Loop 1 = [1] and Loop 2 = [2] 2.0 times.
# Loop 12 = [1 1 2 2] breaks into Loop 0 = [] and Loop 3 = [1 1] 2.0 times.
# Loop 12 = [1 1 2 2] breaks into Loop 0 = [] and Loop 5 = [2 2] 2.0 times.
# Loop 13 = [1 2 1 2] breaks into Loop 1 = [1] and Loop 1 = [1] 2.0 times.
# Loop 13 = [1 2 1 2] breaks into Loop 2 = [2] and Loop 2 = [2] 2.0 times.
# Loop 14 = [1 2 2 2] breaks into Loop 0 = [] and Loop 4 = [1 2] 4.0 times.
# Loop 14 = [1 2 2 2] breaks into Loop 1 = [1] and Loop 2 = [2] 2.0 times.
# Loop 15 = [2 2 2 2] breaks into Loop 0 = [] and Loop 5 = [2 2] 8.0 times.
# Loop 15 = [2 2 2 2] breaks into Loop 2 = [2] and Loop 2 = [2] 4.0 times.
# Main Program
# large_n_energy (9.635052032312128-2.9016001981352e-16j)
# %%%%%%% Concatenated gradient
# (-16.378652200585446-9.18045965197626e-16j)
# (-18.85420880770155+6.516420416995222e-16j)
# (6.938039422584025+2.120934126554631e-15j)
# (-11.335754622565014-1.3938666812571811e-15j)
# (39.61557279757263-2.246667358295515e-15j)
# (1.4987325537056984-2.594338424396372e-16j)
# (1.877309170559913-1.786101831194561e-16j)
# (1.56375151247869-8.649652732942827e-16j)
# (-0.8351622399850966+6.907885812898295e-16j)
# (4.44858759144575-6.38361867948616e-16j)
# (-0.3745247928261502+2.5465377422927266e-16j)
# (1.8389609799636113+5.098698135036978e-16j)
# (1.2091029968217937+1.693056467764179e-16j)
# (0.6345376556531466+1.2555376541201135e-15j)
# (4.607114463083462-1.7705049458135678e-15j)
# (1.4495324280403937e-16-7.006876856414405e-18j)
# (1.9245356478068703e-16-4.814048089634652e-18j)
# (-5.706161643518385e-18+3.5791844153873425e-18j)
# (-6.240828742841193e-17-3.074703127746185e-18j)
# (1.059984564613368e-17-1.5353970109228158e-18j)
# (1.590788805449077e-16-1.682760879824295e-18j)
# (4.8264091578105416e-17+2.0899563802360727e-18j)
# (3.1546809798575907e-16+2.2012144567343117e-18j)
# (-2.7493423752612534e-16+4.9939040364446e-18j)
# (2.5438735984897037e-16-8.922028009072085e-18j)
# (-1.4639907657453259e-16-1.2558044960298327e-17j)
# (4.970774724286944e-17-1.3830442127150849e-18j)
# (-4.462853393311032e-17+3.517782291486187e-18j)
# (-2.0413218024295476e-16-8.243980771939469e-19j)
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 94
#          Function evaluations: 95
#          Gradient evaluations: 95
# 31.046265933 sec in minimization
# Energy = 8.679303683063253e-30
# Loop, 0 ,=, [] ,has value, 1.000000 ,imaginary part, 0.000000
# Loop, 1 ,=, [1] ,has value, -0.050511 ,imaginary part, 0.000000
# Loop, 2 ,=, [2] ,has value, -0.050510 ,imaginary part, 0.000000
# Loop, 3 ,=, [1 1] ,has value, 1.010214 ,imaginary part, 0.000000
# Loop, 4 ,=, [1 2] ,has value, 0.002539 ,imaginary part, 0.000000
# Loop, 5 ,=, [2 2] ,has value, 1.010208 ,imaginary part, -0.000000
# Loop, 6 ,=, [1 1 1] ,has value, -0.204283 ,imaginary part, 0.000000
# Loop, 7 ,=, [1 1 2] ,has value, -0.050787 ,imaginary part, 0.000000
# Loop, 8 ,=, [1 2 2] ,has value, -0.050785 ,imaginary part, 0.000000
# Loop, 9 ,=, [2 2 2] ,has value, -0.204161 ,imaginary part, -0.000000
# Loop, 10 ,=, [1 1 1 1] ,has value, 2.065230 ,imaginary part, 0.000000
# Loop, 11 ,=, [1 1 1 2] ,has value, 0.007459 ,imaginary part, 0.000000
# Loop, 12 ,=, [1 1 2 2] ,has value, 1.011895 ,imaginary part, -0.000000
# Loop, 13 ,=, [1 2 1 2] ,has value, 0.010227 ,imaginary part, -0.000000
# Loop, 14 ,=, [1 2 2 2] ,has value, 0.007390 ,imaginary part, 0.000000
# Loop, 15 ,=, [2 2 2 2] ,has value, 2.062796 ,imaginary part, -0.000000
# Loop, 16 ,=, [1 1 1 1 1] ,has value, -0.845015 ,imaginary part, 0.000000
# Loop, 17 ,=, [1 1 1 1 2] ,has value, -0.091133 ,imaginary part, 0.000000
# Loop, 18 ,=, [1 1 1 2 2] ,has value, -0.018151 ,imaginary part, 0.000000
# Loop, 19 ,=, [1 1 2 1 2] ,has value, -0.127398 ,imaginary part, -0.000000
# Loop, 20 ,=, [1 1 2 2 2] ,has value, -0.049222 ,imaginary part, -0.000000
# Loop, 21 ,=, [1 2 1 2 2] ,has value, -0.179630 ,imaginary part, 0.000000
# Loop, 22 ,=, [1 2 2 2 2] ,has value, -0.078923 ,imaginary part, -0.000000
# Loop, 23 ,=, [2 2 2 2 2] ,has value, -0.796576 ,imaginary part, 0.000000
# Loop, 24 ,=, [1 1 1 1 1 1] ,has value, 4.690867 ,imaginary part, 0.000000
# Loop, 25 ,=, [1 1 1 1 1 2] ,has value, 0.032301 ,imaginary part, 0.000000
# Loop, 26 ,=, [1 1 1 1 2 2] ,has value, 2.079288 ,imaginary part, 0.000000
# Loop, 27 ,=, [1 1 1 2 1 2] ,has value, -0.025273 ,imaginary part, 0.000000
# Loop, 28 ,=, [1 1 2 1 1 2] ,has value, 0.390165 ,imaginary part, -0.000000
# Loop, 29 ,=, [1 1 1 2 2 2] ,has value, -0.180808 ,imaginary part, -0.000000
# Loop, 30 ,=, [1 1 2 1 2 2] ,has value, 0.096654 ,imaginary part, -0.066522
# Loop, 31 ,=, [1 1 2 2 1 2] ,has value, 0.096654 ,imaginary part, 0.066522
# Loop, 32 ,=, [1 2 1 2 1 2] ,has value, 0.051969 ,imaginary part, 0.000000
# Loop, 33 ,=, [1 1 2 2 2 2] ,has value, 2.009629 ,imaginary part, -0.000000
# Loop, 34 ,=, [1 2 1 2 2 2] ,has value, 0.005895 ,imaginary part, 0.000000
# Loop, 35 ,=, [1 2 2 1 2 2] ,has value, 0.500066 ,imaginary part, 0.000000
# Loop, 36 ,=, [1 2 2 2 2 2] ,has value, 0.026645 ,imaginary part, 0.000000
# Loop, 37 ,=, [2 2 2 2 2 2] ,has value, 4.667165 ,imaginary part, -0.000000
# SD, [1] ,i, 1 ,=, (-3.2127078775090467e-15+0j)
# SD, [2] ,i, 2 ,=, (-2.5604518505417673e-15+1.4695207090403653e-19j)
# SD, [1 1] ,i, 3 ,=, (-3.9968028886505635e-15+0j)
# SD, [1 2] ,i, 4 ,=, (-7.90513488002631e-15-4.547034092960876e-19j)
# SD, [2 2] ,i, 5 ,=, (6.661338147750939e-16+6.539521856595786e-18j)
# SD, [1 1 1] ,i, 6 ,=, (-4.440892098500626e-15+0j)
# SD, [1 1 2] ,i, 7 ,=, (-4.163336342344337e-17+9.140765182841901e-20j)
# SD, [1 2 2] ,i, 8 ,=, (-1.1796119636642288e-15-3.0648112465154914e-17j)
# SD, [2 2 2] ,i, 9 ,=, (-5.828670879282072e-15+2.8240674978250956e-17j)
# SD, [1 1 1 1] ,i, 10 ,=, (-2.1316282072803006e-14+0j)
# SD, [1 1 1 2] ,i, 11 ,=, (-1.7175497135646367e-14-1.267752611704515e-18j)
# SD, [1 1 2 2] ,i, 12 ,=, (-4.440892098500626e-15+2.9533645061566507e-19j)
# SD, [1 2 1 2] ,i, 13 ,=, (-2.6957602816679582e-15+1.2950980783999091e-17j)
# SD, [1 2 2 2] ,i, 14 ,=, (-1.5312404122447276e-14-1.3383675801105137e-16j)
# SD, [2 2 2 2] ,i, 15 ,=, 1.8984729794925144e-16j
# c = 0.0 , g_3 = 0.05 , g_4= 0.0
# No of loops = 37 , lmax = 4 , Omega is 15 x 15 matrix
# N = 5 , No of master variables =  30
# Fluctuations spectrum
# [0.94891428 0.95773054 1.95879726 1.96258808 1.97722893 2.8370215
#  2.88413269 2.94231496 2.96895672 3.99918692 4.0055788  4.10058993
#  4.13752998 4.35878161 4.43980031]
# V_2 total contribution
# [0.94891428 0.95773054 1.95879726 1.96258808 1.97722893 2.8370215
#  2.88413269 2.94231496 2.96895672 3.99918692 4.0055788  4.10058993
#  4.13752998 4.35878161 4.43980031]
# Master Field
# -0.657154418057911
# -0.8336842166193525
# 1.307277914898121
# 3.1520844943535167
# -3.5332506505525503
# 0.8215287547581009
# 0.9579713882984128
# 0.293028733599939
# -0.4951685437003713
# 0.8111184181006372
# -0.5689054477532314
# -1.0018771301788088
# 0.44520929034360524
# 0.6578853341035973
# 1.1364133487434414
# 0.20815849750704438
# 0.004469900498567334
# -0.18980196921234754
# 0.41153076542796163
# 0.5983565179827895
# 1.4648496951980097
# -1.2489716239058
# 1.107732179176104
# -0.10040587286071208
# 0.3630058563507964
# 1.0305233928620294
# -0.7817591345174553
# 0.3818417408588671
# -0.39212406463221383
# -0.09416723945054058
# [-0.65715442 -0.83368422  1.30727791  3.15208449 -3.53325065  0.82152875
#   0.95797139  0.29302873 -0.49516854  0.81111842 -0.56890545 -1.00187713
#   0.44520929  0.65788533  1.13641335  0.2081585   0.0044699  -0.18980197
#   0.41153077  0.59835652  1.4648497  -1.24897162  1.10773218 -0.10040587
#   0.36300586  1.03052339 -0.78175913  0.38184174 -0.39212406 -0.09416724]
# Info extracted from file
# 0.0
# 0.05
# 0.0
# 4
# 5
# Extracted Master Field
# [-0.65715442 -0.83368422  1.30727791  3.15208449 -3.53325065  0.82152875
#   0.95797139  0.29302873 -0.49516854  0.81111842 -0.56890545 -1.00187713
#   0.44520929  0.65788533  1.13641335  0.2081585   0.0044699  -0.18980197
#   0.41153077  0.59835652  1.4648497  -1.24897162  1.10773218 -0.10040587
#   0.36300586  1.03052339 -0.78175913  0.38184174 -0.39212406 -0.09416724]
# -0.657154418057911
# -0.8336842166193525
# 1.307277914898121
# 3.1520844943535167
# -3.5332506505525503
# 0.8215287547581009
# 0.9579713882984128
# 0.293028733599939
# -0.4951685437003713
# 0.8111184181006372
# -0.5689054477532314
# -1.0018771301788088
# 0.44520929034360524
# 0.6578853341035973
# 1.1364133487434414
# 0.20815849750704438
# 0.004469900498567334
# -0.18980196921234754
# 0.41153076542796163
# 0.5983565179827895
# 1.4648496951980097
# -1.2489716239058
# 1.107732179176104
# -0.10040587286071208
# 0.3630058563507964
# 1.0305233928620294
# -0.7817591345174553
# 0.3818417408588671
# -0.39212406463221383
# -0.09416723945054058
# '\nfor i in range (omega_size):\n    for j in range (num_loops+1):k in range (num_loops+1)\n##print ("second grad_1 ",  grad_1 )\n\ngrad_1+=np.sum (np.array([[(-2*LnJ[i]*(y[i+1,3,k]/2.0 +y[i+1,5,k]/2.0 - c_coupling*y[i+1,4,k]+g3_coupling*y[i+1,6,k]/3.0+g3_coupling*y[i+1,9,k]/3.0)*grad_array_1[k]/ (np.power(nt_hooft, (len(loop_list[k])+2)/2))) for i in range (omega_dim)] for k in range (num_loops+1)]),axis=(0,1))\n'
